# %% [markdown]
# Сравнительный анализ моделей

# %% [markdown]
# | Модель | Количество парамеров | Объем | Битность квантирования | Наличие смешанного текста | Среднее время выполнения (сек) | Степень адекватности | Объем ошибок в тексте |
# |-------|-------|-------|-------|-------|-------|-------|-------|
# | qwen2:1.5b |   1.5b    |  935 Mb   |   4 bit    |  Изредка подмешивает иероглифы     |  11.834   |   0.46    |   0.7  |
# | qwen2:1.5b-instruct-q8_0 |   1.5b    |   1,6GB    |   8 bit    |  Изредка подмешивает иероглифы     |   7.071    |   0.64    |   0.6   |
# | qwen2:7b |   7b    |   4,4GB    |   4 bit    |   Нет   |   57.868    |   0.97   |    0.5   |
# | qwen2.5:1.5b |   1.5b    |   986MB    |   4 bit    |   Изредка подмешивает иероглифы    |    18.181   |    0.38   |   1    |
# | qwen2.5:3b |    3b   |   1.9GB    |   4 bit    |   Нет    |  32.084    |   0.78  |   0.6    |
# | qwen2.5:3b-instruct-q8_0 |   3b    |   3.3 GB    |   8 bit    |   Нет    |   42.756    |   0.83    |   0.4   |
# | qwen2.5:7b |    7b   |  4.7GB     |   4 bit    |   Нет    |   47.776    |   0.98    |   0.1   |
# | llama3.2:3b |    3b   |   2GB   |   4 bit    |  Все тексты на смеси русского и английского     |   26.85    |   0    |   1    |
# | llama3.2:3b-instruct-q8_0 |   3b    |  3.4 GB    |  8 bit     |   Все тексты на смеси русского и английского + иероглифы    |   27.32    |   0    |    1   |
# | gemma2:2b-instruct-q8_0 |   2b    |    2.8 GB   |   8 bit    |    Генерация текста в основном только на английском   |   43.21  |   0.2    |   0.9    |
# | llama3.1:8b-instruct-q4_0 |   8b    |    4.7 GB   |    4 bit   |   Изредка подмешивает иероглифы    |   39.02   |  0.5    |   0.6   |
